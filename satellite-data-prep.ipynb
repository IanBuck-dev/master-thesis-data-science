# %%
import rioxarray
import matplotlib.pyplot as plt
import xarray as xr

fn = '/Users/ian/Repos/uni/sensor-data-ml/data/MODIS-C061_MYD13C2_NDVI__LPDAAC__0.05deg__MONTHLY__UHAM-ICDC__202305__fv0.01.nc'
ds = rioxarray.open_rasterio(fn)

print(ds.dims)
print(ds.attrs)
print(ds.coords)

ds.aerosol.plot()
# Out:
# Frozen({'time': 1, 'x': 7200, 'y': 3600})
# ...
